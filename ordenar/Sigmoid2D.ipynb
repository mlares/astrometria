# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
w0 = 0
w1 = 1.
w2 = 1.

sigmoid = lambda x,y: 1/np.sqrt(1 + 2*np.exp(w0 + w1*x**2 + w2*y**2))

sigmoid = lambda x,y: 1 / np.sqrt(1 + np.exp(-(w0 + w1*x + w2*y)))


xmax = 5
xmin = -xmax

ts = np.arange(xmin,xmax,.1)
fig = plt.figure()
ax = fig.gca(projection='3d')
(XX,YY) = np.meshgrid(ts,ts)
ZZ = np.vectorize(sigmoid)(XX,YY)
ax.plot_surface(XX,YY,ZZ,rstride = 5, cstride = 5, cmap = cm.jet)

# %%
ax.plot_surface(XX,YY,ZZ,rstride = 3, cstride = 3, cmap = cm.jet)
ax.view_init(azim = 180+40,elev = 22)
