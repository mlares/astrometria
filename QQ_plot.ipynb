# %%
import numpy as np
import statsmodels.api as sm
import pylab
import stats
from scipy import stats
import pylab
from matplotlib import pyplot as plt

# %%
test = np.random.weibull(1, 1000)
sm.qqplot(test, line='45')
pylab.show()
# Out:
# /home/mlares/.virtualenvs/astrometria/lib/python3.8/site-packages/statsmodels/graphics/gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
N = stats.norm(loc=3, scale=2)
x = N.rvs(size=100)

# %%
x.mean()
# Out:
# 3.1024077863878214

# %%
fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot()
stats.probplot(x, dist="norm", plot=pylab)
ax.axhline(x.mean())
ax.axhline(x.mean()-x.std())
ax.axhline(x.mean()+x.std())
ax.axvline(0)
ax.axvline(-1)
ax.axvline(1)
pylab.show()

# %%
def qq_plot_norm(loc=0, scale=1, size=100):

    N = stats.norm(loc=loc, scale=scale)
    x = N.rvs(size=100)

    fig = plt.figure(figsize=(10,6))
    stats.probplot(x, dist="norm", plot=pylab)
    pylab.show()

# %%
qq_plot_norm(0, 10, 100)

# %%
(qt, qe), (slope, intercept, r) = stats.probplot(x, dist="norm")

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot()
ax.axline((0, intercept), slope=slope, color='coral')
ax.plot(qt, qe, marker='o', linestyle='None')
ax.grid()

# %%
def qq_norm(loc=0, scale=1, size=100, ref='norm'):
    N = stats.norm(loc=loc, scale=scale)
    x = N.rvs(size=100)
    (qt, qe), (slope, intercept, r) = stats.probplot(x, dist=ref)
    return (qt, qe), (slope, intercept, r)

# %%
stats.distributions.pareto

# %%
res1 = qq_norm(loc=0, scale=1, size=50, ref='norm')
(qt1, qe1), (slope1, intercept1, r1) = res1

# %%
res2 = qq_norm(loc=0, scale=2, size=50, ref='norm')
(qt2, qe2), (slope2, intercept2, r2) = res2

# %%
opts = {'marker': 'o', 'linestyle': 'None'}

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot()
ax.plot(qt1, qe1, **opts)
ax.plot(qt2, qe2, **opts)

# %% [markdown]
# ### Ejemplo con distribucion uniforme

# %%
def qq_norm_rvs(rvs, ref='norm'):
    (qt, qe), (slope, intercept, r) = stats.probplot(rvs, dist=ref)
    return (qt, qe), (slope, intercept, r)

# %%
f = stats.uniform(loc=10, scale=10)
x = f.rvs(size=550)

# %%
fig = plt.figure(figsize=(10, 8))
plt.hist(x, density=True)
t = np.linspace(10, 20, 100)
plt.plot(t, f.pdf(t))

mu = x.mean()
sd = x.std()
N = stats.norm(loc=mu, scale=sd)
plt.plot(t, N.pdf(t))

# %%
(qt, qe), (slope, intercept, r) = stats.probplot(x, dist='norm')

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot()
ax.plot(qt, qe, **opts)
ax.axline((0, intercept), slope=slope, color='coral')

# %% [markdown]
# ### Ejemplo con distribucion f

# %%
f = stats.f(4, 5)

# %%
x = f.rvs(100)

# %%
fig = plt.figure(figsize=(10, 8))
plt.hist(x)
# Out:
# (array([55., 25., 10.,  2.,  3.,  1.,  3.,  0.,  0.,  1.]),
#  array([ 0.06790006,  1.22488466,  2.38186927,  3.53885387,  4.69583848,
#          5.85282308,  7.00980769,  8.16679229,  9.32377689, 10.4807615 ,
#         11.6377461 ]),
#  <BarContainer object of 10 artists>)

# %%
fig = plt.figure(figsize=(10, 8))
plt.hist(x, density=True)
t = np.linspace(0, 10, 100)
plt.plot(t, f.pdf(t))

mu = x.mean()
sd = x.std()
N = stats.norm(loc=mu, scale=sd)
plt.plot(t, N.pdf(t))

# %%
(qt, qe), (slope, intercept, r) = stats.probplot(x, dist='norm')
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot()
ax.plot(qt, qe, **opts)
ax.axline((0, intercept), slope=slope, color='coral')
